# %%
import pandas as pd
import csv

# %%
df = pd.read_csv('osakahotel.csv',sep = None,encoding = 'utf-8')
# Out:
# C:\Users\Renee\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
from plotly.graph_objs import Scatter, Layout
import numpy as np
from plotly.offline import iplot
df
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
#                                                  ﻿name  score    comments  \
# 0                       Residential Hotel Hare Kuromon    9.6     11条住客点评
# 1               Nipponbashi Hanna No.2 Hotel Apartment    NaN         NaN
# 2                         Lore Hostel Dotonbori（道顿堀旅舍）    8.2  2,993条住客点评
# 3                             Hotel Be-zen shimanouchi    7.8     14条住客点评
# 4                      The Dorm Hostel Osaka（大阪啡香书屋旅舍）    9.2  2,455条住客点评
# 5                            Osaka Hana Hostel（大阪花宿旅舍）    8.9  1,262条住客点评
# 6                               Dotonbori Hotel（道顿堀酒店）    8.7    504条住客点评
# 7                         Bijou Suites Akari（比约明亮套房公寓）    9.2     69条住客点评
# 8        Apollo Couples Apartment at Namba（阿波罗情侣纳姆巴公寓）    9.0    100条住客点评
# 9                              Hotel Le Botejour Nanba    7.9    527条住客点评
# 10         RakutenSTAYHOSTEL Nambaminami（那木巴米娜米拉库塔斯酒店）    8.5    167条住客点评
# 11        Shinsaibashi-Higashi Crystal Hotel（心斋桥东水晶酒店）    8.3    349条住客点评
# 12              HOTEL THE FLAG Shinsaibashi（心斋桥法拉格酒店 ）    9.3    977条住客点评
# 13              The Bridge Hotel Shinsaibashi（心斋桥大桥酒店）    8.7    763条住客点评
# 14                           Nisshin Namba Inn（日进南芭旅馆）    8.7    359条住客点评
# 15                                             ルポゼ・島之内    NaN         NaN
# 16                        Tanimachi LUXE HOTEL（谷町奢华酒店）    8.1  1,118条住客点评
# 17             Hotel WBF Namba Nippombashi（难波日本桥WBF酒店）    8.8     75条住客点评
# 18                       Kuromon Crystal Hotel（黑门水晶酒店）    8.7    217条住客点评
# 19                   Crest Court Nipponbashi（日本桥鹤立苑公寓）    8.2     79条住客点评
# 20         Namba high class residence 13（难波高档住宅13号公寓 ）    8.7     30条住客点评
# 21   Hearton Hotel Shinsaibashi Nagahoridouri（哈托恩心斋...    8.7    378条住客点评
# 22        Comfort Hotel Osaka Shinsaibashi（大阪心斋桥康福特酒店）    8.1    373条住客点评
# 23    Designer Pent House Doutonbori East（彭特达顿波利东设计公寓）    9.1     40条住客点评
# 24   Hotel Oriental Express Osaka Shinsaibashi（大阪心斋...    8.8     46条住客点评
# 25                              Namba_KUROMON_KMR0005B    7.7      6条住客点评
# 26                                   Rela Shinsaibashi    9.4      8条住客点评
# 27                   Hotel Code Shinsaibashi（心斋桥柯德酒店 ）    8.3  1,025条住客点评
# 28                              Namba_Kuromon_KMR0001B    7.9      6条住客点评
# 29     Hotel Felice Shinsaibashi By Relief（费利斯心斋桥颐养酒店）    9.2     51条住客点评
# ..                                                 ...    ...         ...
# 540                            Apartment in Osaka 9709    NaN         NaN
# 541                 Osaka Hotel Live Artex（莱弗阿泰克斯大阪酒店）    8.3    119条住客点评
# 542                                   RELA Shimanouchi    NaN         NaN
# 8           大阪【难波】 – 显示在地图上  Apollo Couples Apartment at Namba酒店距离难波车站（Namb...
# 9      中央区, 大阪【难波】 – 显示在地图上  Hotel Le Botejour Annex酒店提供按摩服务和24小时服务的前台，距离难波...
# 10        大阪【南部地区】 – 显示在地图上  RakutenSTAYHOSTEL Nambaminami酒店位于大阪，距离新世界（Shin...
# 11   中央区, 大阪【南部地区】 – 显示在地图上  Shinsaibashi-Higashi Crystal Hotel酒店位于大阪（Osaka...
# 12    中央区, 大阪【心斋桥】 – 显示在地图上  这家三星级的HOTEL THE FLAG Shinsaibashi酒店位于大阪（Osaka）...
# 13    中央区, 大阪【心斋桥】 – 显示在地图上  The Bridge Hotel Shinsaibashi酒店于2016年11月开业，是一家...
# 14          大阪【难波】 – 显示在地图上   Nisshin Namba Inn宾馆距离大国町地铁站（Daikokucho Subway...
# 15    中央区, 大阪【道顿堀】 – 显示在地图上  Set 1 km from Glico Man Sign, ルポゼ・島之内 is locat...
# 16        大阪【南部地区】 – 显示在地图上  Tanimachi LUXE HOTEL无烟酒店位于大阪市（Osaka），距离难波城（Nam...
# 17   中央区, 大阪【南部地区】 – 显示在地图上  Hotel WBF Namba Nippombashi酒店位于大阪（Osaka）的中央区（C...
# 18   中央区, 大阪【南部地区】 – 显示在地图上  Kuromon Crystal Hotel酒店位于大阪（Osaka），距离难波城（Namba...
# 19   中央区, 大阪【南部地区】 – 显示在地图上  Crest Court Nipponbashi酒店距离难波城购物中心有700米，提供免费Wi...
# 20          大阪【难波】 – 显示在地图上  Namba high class residence 13公寓位于大阪，距离难波城购物中心仅...
# 21         大阪【心斋桥】 – 显示在地图上  Hearton Hotel Shinsaibashi Nagahoridouri酒店位于大阪...
# 22    中央区, 大阪【心斋桥】 – 显示在地图上  Comfort Hotel Osaka Shinsaibashi经济型酒店距离心斋桥地铁站（...
# 23        大阪【南部地区】 – 显示在地图上  Designer Pent House Doutonbori East公寓位于大阪南区天王寺...
# 24    中央区, 大阪【心斋桥】 – 显示在地图上  Hotel Oriental Express Osaka Shinsaibashi酒店位于大...
# 25     中央区, 大阪【难波】 – 显示在地图上  Namba_KUROMON_KMR0005B is a property set in Os...
# 26    中央区, 大阪【心斋桥】 – 显示在地图上         Just 700 metres from Glico Man Sign and 1.
# 27    中央区, 大阪【心斋桥】 – 显示在地图上  Hotel Code Shinsaibashi酒店于2017年3月开业，位于大阪（Osaka...
# 28   中央区, 大阪【南部地区】 – 显示在地图上  Namba_Kuromon_KMR0001B公寓位于大阪（Osaka）的中央区（Chuo W...
# 29    中央区, 大阪【心斋桥】 – 显示在地图上  Hotel Felice Shinsaibashi By Relief经济型酒店提供位于大阪...
# ..                      ...                                                ...
# 540  中央区, 大阪【南部地区】 – 显示在地图上  Apartment in Osaka 9709 offers accommodation i...
# 541       大阪【南部地区】 – 显示在地图上   Osaka Hotel Live Artex酒店距离Tanimachi Kyu-Chome...
# 542  中央区, 大阪【南部地区】 – 显示在地图上  Situated in the Chuo Ward district of Osaka, j...
# 543  中央区, 大阪【南部地区】 – 显示在地图上  Boasting air-conditioned accommodation with a ...
# 544  中央区, 大阪【南部地区】 – 显示在地图上  1.4 km from Namba CITY shopping mall, 日本桥民宿202...
# 545         大阪【难波】 – 显示在地图上  Set in the Shinsaibashi, Namba, Yotsubashi dis...
# 546   中央区, 大阪【道顿堀】 – 显示在地图上  Welina Hotel Shinsaibashi offers free WiFi and...
# 547  中央区, 大阪【南部地区】 – 显示在地图上  Situated in Osaka in the Osaka Prefecture regi...
# 548  中央区, 大阪【南部地区】 – 显示在地图上  Boasting air-conditioned accommodation with a ...
# 549       大阪【南部地区】 – 显示在地图上  Hotel Ikutama Love酒店是一家情趣酒店，位于大阪，距离通天（Shitenno...
# 550       大阪【南部地区】 – 显示在地图上  Oasis Daikoku Two offers accommodation in Osak...
# 551         大阪【难波】 – 显示在地图上     Just 1 km from Namba CITY shopping mall and 1.
# 552       大阪【南部地区】 – 显示在地图上  Hotel Awina Osaka酒店提供带免费有线网络和平面电视的住宿，距离大阪上本町火车...
# 553       大阪【南部地区】 – 显示在地图上  Hills 1（Adult Only）情趣酒店位于大阪（Osaka），距离四天王寺（Shit...
# 554  中央区, 大阪【南部地区】 – 显示在地图上         Situated 1.1 km from Glico Man Sign and 1.
# 555       大阪【南部地区】 – 显示在地图上  Located in Osaka in the Osaka Prefecture regio...
# 556  中央区, 大阪【南部地区】 – 显示在地图上  Located in Osaka, just 1.5 km from Glico Man S...
# 557       大阪【南部地区】 – 显示在地图上  Yoshino Ryokan日式旅馆位于大阪（Osaka），提供免费WiFi，距离四天王寺（...
# 558   中央区, 大阪【道顿堀】 – 显示在地图上  Ogu's River side room公寓位于大阪（Osaka），距离Glico Man...
# 559         大阪【难波】 – 显示在地图上  仅为成人设计的Namba Little Chapel情趣酒店距离JR难波站（JR Namba...
# 560       大阪【南部地区】 – 显示在地图上  Hotel Zen情趣酒店位于大阪，仅适合成人入住，距离四天王寺（Shitennoji）有9...
# 561       大阪【南部地区】 – 显示在地图上  Hotel Atlantis (Adult Only)酒店位于大阪市（Osaka）的Ueho...
# 562       大阪【南部地区】 – 显示在地图上  Park Side inn Nipponbashi宾馆位于大阪（Osaka），距离难波城（N...
# 563   中央区, 大阪【道顿堀】 – 显示在地图上  Fine Aroma Dotonbori (Adult Only)情趣酒店距离热闹的Doto...
# 564  中央区, 大阪【南部地区】 – 显示在地图上  Apartment in Shimanouchi 403公寓位于大阪（Osaka），距离格力...
# 565  中央区, 大阪【南部地区】 – 显示在地图上  S1 Apartment in Nipponbashi公寓位于大阪（Osaka）的中央区（C...
# 566  中央区, 大阪【南部地区】 – 显示在地图上  Osaka Hitomi House No2公寓位于大阪（Osaka）的中央区（Chuo W...
# 567   中央区, 大阪【心斋桥】 – 显示在地图上  Foga Inn旅馆位于大阪（Osaka），提供免费WiFi，距离格力高人形广告牌（Glic...
# 568  中央区, 大阪【南部地区】 – 显示在地图上  T1 Apartment in Nipponbashi公寓位于大阪（Osaka），距离Nam...
# 569  中央区, 大阪【南部地区】 – 显示在地图上  Hotel Osaka Keiko酒店提供经过翻修的简约客房，距离Nipponbashi S...
#
# [570 rows x 5 columns]

# %%
南部地区=df['address'].apply(lambda t:'南部地区' in str(t)).aggregate('sum')
心斋桥=df['address'].apply(lambda t:'心斋桥' in str(t)).aggregate('sum')
道顿堀=df['address'].apply(lambda t:'道顿堀' in str(t)).aggregate('sum')
难波=df['address'].apply(lambda t:'难波' in str(t)).aggregate('sum')

# %%
import plotly.plotly as py
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='sayaka', api_key='gIQREJIrX2NDqdflpwS8')

labels = ['南部地区','难波','心斋桥','道顿堀']
values = [南部地区,难波,心斋桥,道顿堀]
colors = ['#CD5555', '#CD6A6A', '#CD9B9B', '#FFC1C1']

trace = go.Pie(labels=labels, values=values,
               hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=20),
               marker=dict(colors=colors, 
                           line=dict(width=1)))

py.iplot([trace], filename='Favourite Location')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sayaka/2.embed" height="525px" width="100%"></iframe>

# %%
# import jieba
# f = open('osakahotel.csv',encoding='utf-8').read().split('\n')  
# with open('osakahotel.csv','rt',encoding='utf-8') as csvfile:
#     reader = csv.reader(csvfile)
#     column = [row[4] for row in reader]

# Keywords=[]
# for i in range(len(column)):
#     result=[]
#     seg_list = jieba.cut(column[i])
#     for n in seg_list :
#         result.append(n)
#     Keywords.append(result)

# file=open('keywords.csv','w',encoding='utf-8')
# writer = csv.writer(file)
# writer.writerows(Keywords)
# file.close() 

# words = jieba.cut(f)
# stopwords = list
# stopwords.extend(['位于','大阪','距离','中央区','（','和','Osaka','）','.','。','，','的','...','不到','km','and','from','with','situated','of','just','is','有','in','带','、','仅','以及'])
# Keywords= []
# for word in words:
#     if word not in stopwords and len(word)>1: 
#         Keywords.append(word)
        
# file=open('keywords.csv','w')
# writer = csv.writer(file)
# writer.writerows(Keywords)
# file.close() 

import jieba
text = open('osakahotel.csv',"rb").read()
words = jieba.cut(text)
filepath = 'stopwords.txt'
stopwords = [line.strip() for line in open(filepath, 'r').readlines()]
Keywords= []
for word in words:
    if word not in stopwords and len(word)>1: 
        Keywords.append(word)

file=open('keywords.csv','w')
writer = csv.writer(file)
writer.writerows(Keywords)
file.close()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text = open('keywords.csv','r').read()
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

wordcloud.to_file('Osaka.jpg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-6f96ae6499f3> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 text = open('keywords.csv','r').read()
# ----> 4 wordcloud = WordCloud().generate(text)
#       5 plt.imshow(wordcloud)
#       6 plt.axis('off')
#
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     603         self
#     604         """
# --> 605         return self.generate_from_text(text)
#     606
#     607     def _check_generated(self):
#
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %%
df['comments'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-98a7cea5a08e> in <module>()
# ----> 1 df['comments'].value_count()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value_count'
